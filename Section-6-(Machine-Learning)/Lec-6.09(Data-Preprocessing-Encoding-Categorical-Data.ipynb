# %% [markdown]
# ---
#  <img align="left" width="75" height="75"  src="https://upload.wikimedia.org/wikipedia/en/c/c8/University_of_the_Punjab_logo.png">
#
# <h1 align="center">Department of Data Science</h1>
# <h1 align="center">Course: Tools and Techniques for Data Science</h1>
#
# ---
# <h3><div align="right">Instructor: Muhammad Arif Butt, Ph.D.</div></h3>

# %% [markdown]
# <h1 align="center">Lecture 6.9 (Data Preprocessing: Encoding Categorical Data)</h1>

# %% [markdown]
# <a href="https://colab.research.google.com/github/arifpucit/data-science/blob/master/Section-4-Mathematics-for-Data-Science/Lec-4.1(Descriptive-Statistics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <img align="center" width="900" src="images/ml-topimg1.png"  >

# %% [markdown]
# # Learning agenda of this notebook
#
# - Overview of Data Pre-Processing and Feature Engineering
# - Understanding Data Types
# - Encoding Categorical Data (What? Why? and How?)
# - A Step-by-Step Hello World to Encode Categorical Data
#     - Scikit-Learn's `LabelEncoder()` vs `OrdinalEncoder()`
#     - Encoding Nominal Variables using Pandas `get_dummies()` and Scikit-Learn's `OneHotEncoder()`
# - Perform Train-Test-Split and then do the Transformations
# - Using ColumnTransformer for Encoding and Imputation

# %% [markdown]
# # 1. Overview of  Data Pre-Processing and Feature Engineering
# - `Data Preprocessing` involves actions that we need to perform on the dataset in order to make it ready to be fed to the machine learning model.
# - `Feature Engineering` is the process of using domain knowledge to extract features from raw data via data mining techniques.<br><br>
#
# <img align="center" width="800" src="images/housing-dataset3.png"  >
# <br><br>
#
# - Pre-processing package of sklearn provides a bundle of utility functions and transformer classes for data preprocessing (will cover later).
#     - **Detecting and handling outliers**
#         - Univariate (Z-Score, IQR, Percentiles)
#         - Multivariate Analysis (Depth-based, Distance-based, Density-based methods)
#         - Trimming, Capping/Winsorization, Discritization
#     - **Missing values Imputation**
#         - Univariate Imputation (Panda's `fillna()` method, Sklearn's `SimpleImputer()` transformer)
#         - Multivariate Imputation (Sklearn's `IterativeImputer()` and  `KNNImputer()` transformers)
#     - **Encoding Categorical Features**
#         - Encode Nominal i/p features using Pandas `get_dummies()` and Scikit-Learn's `OneHotEncoder()`
#         - Encode Ordinal i/p features using Scikit-Learn's `OrdinalEncoder()`
#         - Encode categorical o/p column using Scikit-Learn's `LabelEncoder()`
#     - **Feature Scaling**
#         - Use numPy to perform maxabs, minmax, standard and robust scaling
#         - Use Sklearn's `MaxAbsScalar` , `MinMaxScalar`, `StandardScalar`, `RobustScalar` transformers
#     - **Extracting Information**
#         - Use Sklearn's `CountVectorizer`, `DictVectorizer` , `TfidfVectorizer`, and `TfidfTransformer`
#     - **Combining Information**
#         - Use `FeatureUnion`, `Pipeline`, `PCA`

# %% [markdown]
# # 2. Understanding Data Types
# <center><h3 align="center"><div class="alert alert-success" style="margin: 20px">Numerical data is a type of data that expresses information in the form of numbers, while Categorical data is a type of data that is used to group information with similar characteristics</h3></center>
#
# <img align="center" width="800" src="images/datatypes2.png"  >
# <br><br>
# <img align="center" width="1000" src="images/titanic.png"  >

# %% [markdown]
# # 3. Encoding Categorical Data (What? Why? and How?)
# <center><h4 align="center"><div class="alert alert-success" style="margin: 20px">Encoding categorical data is a process of converting it into numerical values, so that it could be fed to machine learning models</h4></center>
#
# - **Why do we need to encode categorical data?** Most machine learning algorithms cannot handle categorical variables unless we convert them to numerical values. Many algorithm’s performances even vary based upon how the categorical variables are encoded
#
#
# <img align="center" width="550" src="images/encoders.png"  >
#
# Python Category Encoders: http://contrib.scikit-learn.org/category_encoders/

# %% [markdown]
# # 4. A Step-by-Step Hello World to Encode Categorical Data

# %% [markdown]
# ## a. Load Dataset

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('datasets/disease.csv')
df.sample(n=7, random_state=54)

# %%
df.shape

# %%
df.nunique()

# %%
df.info()

# %%
df.disease.value_counts()

# %% [markdown]
# ## b. Scikit-Learn's LabelEncoder vs OrdinalEncoder
# <center><h4 align="center"><div class="alert alert-success" style="margin: 20px">Label Encoding is a popular encoding technique for handling categorical variables, which assign each category value a unique integer starting from 0 to n-1 based on alphabetical ordering</h4></center>
#
# - `LabelEncoder` is used for encoding output variable while `OridnalEncoder` is used for encoding input feature variables of ordinal type, having an intrinsic order.
# - `LabelEncoder` can fit one column at a time while `OrdinalEncoder` can fit multiple columns at the same time.
# - Finally both encoders sort the values of a column alphabetically and then assign them the integer values. For example, in case of city column having two values "Islamabad" and "Karachi", Islamabad will be assigned an integer value of 0, while Karachi will be assigned a value of 1. However, in case of `OrdinalEncoder`, we can mention what integer values should be assigned to each specific category.
#
# [Scikit Learn's LabelEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html)
#
# [Scikit Learn's OrdinalEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OrdinalEncoder.html)

# %% [markdown]
# ### Apply LabelEncoder on `disease` Target Label

# %%
df.head()

# %%
y = df.iloc[:, -1]
y

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y)

# %%
arr_disease = le.transform(y)

# %%
le.classes_

# %%
arr_disease

# %%
arr_disease.shape

# %%
df

# %% [markdown]
# ### Apply OrdinalEncoder on `bp` and  `cough` Features

# %%
df.head()

# %%
X_bp_cough = df.iloc[:, 3:5]
X_bp_cough.head()

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
oe.fit(X_bp_cough)
oe.categories_

# %% [markdown]
# >- The values of column are sorted alphabatically and then assigned integer values from zero onwards

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['low', 'normal', 'high'],['Mild', 'Moderate', 'Strong']], dtype=np.int8)
oe.fit(X_bp_cough)
oe.categories_

# %% [markdown]
# >- OrdinalEncoder, unlike LabelEncoder can assign specific integer values by specifying the categories argument

# %%
arr_bp_cough = oe.transform(X_bp_cough)
arr_bp_cough.shape

# %%
arr_bp_cough

# %% [markdown]
# ## c. Encoding Nominal Variables using OneHotEncoder
# <center><h4 align="center"><div class="alert alert-success" style="margin: 20px">One Hot Encoding is the process of creating dummy variables and each category is represented as a one-hot vector</h4></center>
#
# <img align="center" width="600" src="images/onehotencoding.png"  >
#
# - **Limitations:**
#     - `Multicollinearity`
#         - If you add the one-hot vector they sum up to one. For LinearRegression we know that the input features should not have any correlation with each other, rather should be independent.
#         - Solution: Use Dummy variable trap by dropping one of the dummy column.
#     - `Curse of dimensionality`
#         - Suppose we have a feature column which has 100 unique values. Now if we try to encode this feature using one-hot encoding we will get 99 columns. This will increase the dimension of the overall dataset which will lead to curse of dimensionality.
#         - Solution is you keep the most frequently used say ten categories as separate columns and for all the less frequently used categories you assign a new 11th category say "Others". So this way we will have a total of 10 new columns instead of 99.
#
# >- LabelEncoder donot work for linear models, SVMs, or neural networks as their data needs to be standardized.
# >- One hot encoding overcomes the limitations of label encoding and can be used in both tree-based and non-tree-based machine learning algorithms.

# %% [markdown]
# ### Apply `pd.get_dummies` on `gender` and `city` Columns

# %%
df.head()

# %%
X_gender = df.iloc[:, 0:1]
X_gender.head()

# %%
#pd.get_dummies(data=X_gender)
pd.get_dummies(data=X_gender,drop_first=True)

# %%
pd.get_dummies(data=df, columns=['gender', 'city'], drop_first=True)

# %% [markdown]
# ### Apply `OneHotEncoder` on  `gender` and `city` Column

# %%
X_gender_city = df.iloc[:, 0:2]
X_gender_city

# %%
X_gender_city['city'].nunique()

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first',sparse=False,dtype=np.int32)
ohe.fit(X_gender_city)

# %%
ohe.categories_

# %%
arr_gender_city = ohe.transform(X_gender_city)
arr_gender_city.shape

# %%
arr_gender_city

# %% [markdown]
# # 5. Perform Train-Test-Split and then do the Transformations
# - A better approach is to train-test-split first and then do the encoding so that there is no data leakage.
# - Call `fit_transform()` on the training data, and only `transform()` on the test data. (NEVER call `fit()` on training data)
# - Almost all feature engineering like encoding, standarisation, normalisation etc should be done after train-test-split.

# %% [markdown]
# ## a. Load Dataset

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
df = pd.read_csv('datasets/disease.csv')
df.head()

# %% [markdown]
# ## b. Do a Train-Test-Split

# %%
X = df.drop('disease', axis=1)
X

# %%
y = df['disease']
y

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=54)
len(X_train), len(y_train), len(X_test), len(y_test)

# %%
X_train.head()

# %%
y_train.head()

# %%
X_test.head()

# %%
y_test.head()

# %% [markdown]
# ## c. Apply OneHotEncoder to `gender` and `city` Columns

# %%
# OneHotEncoding -> gender,city
ohe = OneHotEncoder(drop='first',sparse=False,dtype=np.int32)

#Call fit() on the training data
ohe.fit(X_train[['gender','city']])
#Call transform() on both the training data as well as on the testing data
X_train_gender_city = ohe.transform(X_train[['gender','city']])
X_test_gender_city = ohe.transform(X_test[['gender','city']])

X_train_gender_city.shape, X_test_gender_city.shape

# %% [markdown]
# > One column for gender and three columns for city

# %% [markdown]
# ## d. Apply OrdinalEncoder to `bp` and `cough` Columns

# %%
# Ordinalencoding -> cough
oe = OrdinalEncoder(categories=[['low', 'normal', 'high'],['Mild', 'Moderate', 'Strong']], dtype=np.int8)
#Call fit() on the training data
oe.fit(X_train[['bp', 'cough']])
#Call transform() on both the training data as well as on the testing data
X_train_bp_cough = oe.transform(X_train[['bp', 'cough']])
X_test_bp_cough = oe.transform(X_test[['bp', 'cough']])

X_train_bp_cough.shape, X_test_bp_cough.shape

# %% [markdown]
# ## e. Apply LabelEncoder on `disease` output Column

# %%
le = LabelEncoder()

#Call fit() on the training data
le.fit(y_train)
#Call transform() on both the training data as well as on the testing data
y_train = le.transform(y_train)
y_test = le.transform(y_test)

y_train.shape, y_test.shape

# %%
y_test

# %% [markdown]
# ## f. Apply SimpleImputer to `age` Column

# %%
df.info()

# %%
df.age.isnull().sum()

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values=np.nan, strategy='mean')
#Call fit() on the training data
si.fit(X_train[['age']])
#Call transform() on both the training data as well as on the testing data
X_train_age = si.transform(X_train[['age']])
X_test_age = si.transform(X_test[['age']])

X_train_age.shape, X_test_age.shape

# %%
X_test_age

# %% [markdown]
# ## g. Combine Results
# - We need to combine the three resulting/transformed arrays:
#     - X_train_gender_city, X_train_age, X_train_bp_cough,
#     - X_test_gender_city, X_test_age, X_test_bp_cough

# %% [markdown]
# **Combine the transformed resulting arrays of `Train` Dataset:**

# %%
X_train_gender_city.shape, X_train_bp_cough.shape, X_train_age.shape

# %%
X_train_transformed = np.concatenate((X_train_gender_city, X_train_age, X_train_bp_cough),axis=1)
X_train_transformed.shape

# %%
X_train_transformed

# %% [markdown]
# **Combine the transformed resulting arrays of `Test` Dataset:**

# %%
X_test_gender_city.shape, X_test_bp_cough.shape, X_test_age.shape

# %%
X_test_transformed = np.concatenate((X_test_gender_city, X_test_age, X_test_bp_cough),axis=1)
X_test_transformed.shape

# %%
X_test_transformed

# %% [markdown]
# **Convert `X_train_transformed` array to a Dataframe for better visualization:**

# %%
X_train_transformed_df = pd.DataFrame(X_train_transformed, 
                                      columns=['gender','city_1','city_2','city_3','age','bp','cough'])

# %%
X_train.head()

# %%
X_train_transformed_df.head()

# %% [markdown]
# **Convert `X_test_transformed` array to a Dataframe for better visualization:**

# %%
X_test_transformed_df = pd.DataFrame(X_test_transformed, 
                                     columns=['gender','city_1','city_2','city_3','age','bp','cough'])

# %%
X_test.head()

# %%
X_test_transformed_df.head()

# %% [markdown]
# # 6. Using ColumnTransformer for Encoding and Imputation
# [Data Transformers in Scikit-Learn:](https://scikit-learn.org/stable/data_transforms.html)
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">ColumnTransformer allows to apply different Transformers on different columns of our dataset in a simple and elegant way</h3>

# %%
# One-Hot-Encoder for gender and city column
ohe = OneHotEncoder(drop='first',sparse=False,dtype=np.int32)
# OrdinalEncoder for bp and cough column
oe = OrdinalEncoder(categories=[['low', 'normal', 'high'],['Mild', 'Moderate', 'Strong']], dtype=np.int8)
# SimpleImputer for age column
si = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
from sklearn.compose import ColumnTransformer
# define ColumnTransformer 
transformer = ColumnTransformer(transformers=[
                                              ('tfm1',   ohe,    ['gender','city']),
                                              ('tfm2',   oe,     ['bp' , 'cough']),
                                              ('tfm3',   si,     ['age'])
                                             ],
                                            remainder='passthrough')
type(transformer)

# %%
#Call fit() on the training data
transformer.fit(X_train)
#Call transform() on both the training data as well as on the testing data
X_train_transformed1 = transformer.transform(X_train)
X_test_transformed1 = transformer.transform(X_test)

X_train_transformed1.shape, X_test_transformed1.shape

# %%
X_train_transformed1

# %%
df

# %%
X_train_transformed_df1 = pd.DataFrame(X_train_transformed1, 
                                      columns=['gender','city_1','city_2','city_3','age','bp','cough'])
X_train_transformed_df1

# %%
X_train

# %% [markdown]
# # Question

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
df = pd.read_csv('datasets/disease.csv')
X = df.drop('disease', axis=1)
y = df['disease']
X.head()
# Out:
#    gender       city   age      bp     cough
# 0    Male     Lahore  60.0     low  Moderate
# 1    Male  Islamabad  27.0     low      Mild
# 2    Male  Islamabad   NaN  normal    Strong
# 3  Female     Lahore  31.0    high  Moderate
# 4  Female    Karachi  65.0    high      Mild

# %%
ohe = OneHotEncoder(drop='first', sparse=False, dtype=np.int32)
si = SimpleImputer(missing_values=np.nan, strategy='mean')
oe = OrdinalEncoder(categories=[['low','normal','high'],['Mild','Moderate','Strong']], dtype=np.int8)

transformer = ColumnTransformer(transformers=[
    ('tfm1', ohe, ['gender','city']),
    ('tfm2', si,  ['age']),
    ('tfm3', oe,['bp','cough']),
    ],
    remainder='passthrough')

transformer.fit_transform(X.head())
# Out:
# array([[ 1.  ,  0.  ,  1.  , 60.  ,  0.  ,  1.  ],
#        [ 1.  ,  0.  ,  0.  , 27.  ,  0.  ,  0.  ],
#        [ 1.  ,  0.  ,  0.  , 45.75,  1.  ,  2.  ],
#        [ 0.  ,  0.  ,  1.  , 31.  ,  2.  ,  1.  ],
#        [ 0.  ,  1.  ,  0.  , 65.  ,  2.  ,  0.  ]])
