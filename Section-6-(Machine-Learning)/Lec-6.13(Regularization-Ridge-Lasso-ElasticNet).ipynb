# %% [markdown]
# ---
#  <img align="left" width="75" height="75"  src="https://upload.wikimedia.org/wikipedia/en/c/c8/University_of_the_Punjab_logo.png">
#
# <h1 align="center">Department of Data Science</h1>
# <h1 align="center">Course: Tools and Techniques for Data Science</h1>
#
# ---
# <h3><div align="right">Instructor: Muhammad Arif Butt, Ph.D.</div></h3>

# %% [markdown]
# <h1 align="center">Lecture 6.13 (Regularization: Ridge, Lasso and ElasticNet)</h1>

# %% [markdown]
# <a href="https://colab.research.google.com/github/arifpucit/data-science/blob/master/Section-4-Mathematics-for-Data-Science/Lec-4.1(Descriptive-Statistics).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <img align="center" width="900" src="images/ml-topimg1.png"  >

# %% [markdown]
# # Learning agenda of this notebook
#
# - Overfit vs Underfit vs Good Fit (A Recap)
#     - What is Overfitting-Underfitting?
#     - How to Detect Overfitting-Underfitting
#     - Bias-Variance Tradeoff
#     - How to Prevent Overfitting?
# - Regularization
#     - Regularization Techniques
#         - Ridge (L2)
#         - Lasso (L1)
#         - ElasticNet (L1+L2)
#         - An intution of Regularization for 2-D Data
#     - Cost Functions for Ridge, Lasso, and ElasticNet Regression
# - Scikit-Learn Estimators for Regularization
#     - Example 1
#     - Example 2
#     - Example 3

# %% [markdown]
# # 1. Overfit vs Underfit vs Good Fit (A Recap)

# %% [markdown]
# ## a. What is Overfitting-Underfitting?
# <img align="center" width="1000" src="images/overfit-underfit1.png"  >

# %% [markdown]
# ## b. How to Detect Overfitting-Underfitting
#
# <img align="center" width="900" src="images/overfit-underfit2.png"  >

# %% [markdown]
# ## c. Bias-Variance Tradeoff
#
# <img align="center" width="700" src="images/bias-variance1.png"  >

# %% [markdown]
# ## d. How to Prevent Overfitting?
# <img align="center" width="900" src="images/overfitting-prevention.png"  >

# %% [markdown]
# >- **Feature Selection:** Keep only those features in your dataset which are correlated with output column and not with each other. Two ways to proceed are Forward selection and Backward selection.
# >- **Early Stopping:** Used when you are training a learning algorithm iteratively and is most commonly used in Deep Learning. However, if you stop the training/learning process too early may lead to underfitting as well.
# >- **Cross Validation:** Generate multiple train-test splits from your training data and tune hyperparameters of your model using techniques like GridSearch and RandomizedSearch CV.
# >- **Bagging/Boosting:** Bagging and Boosting are ensemble techniques that combine prediction using multiple estimators. Bagging is an acronym for Boot Strap Aggregation, which attempts to reduce the chance of overfitting of complex models. Example is Random Forrest Classifier. Boosting attempts to train large number of weak learners in sequence. Examples are AdaBoost and XGBoost.
# >- **Regularization:**

# %% [markdown]
# # 2. Regularization
# <center><h3 align="center"><div class="alert alert-success" style="margin: 20px">Regularization techniques are used to calibrate the linear regression models in order to minimize the adjusted loss function and prevent overfitting and underfitting</h3></center>
#
# <img align="center" width="800" src="images/regularization3.jpeg"  >

# %% [markdown]
# ## a. Regularization Techniques
# <img align="center" width="1000" src="images/regularization-main.png"  >
#
# - **How to find the coefficients for the minimum value of RSS error function?**
# >- Solve the model parameters analytically and arrive at a closed form solution by setting the gradient of loss function equal to zero and solving the resultant equation for the coefficient vector $\beta$.
# >- Use Gradient Descent, which is an iterative optimization algorithm used to find the local minima of a differentiable function. The main idea is to take repeated steps in the opposite direction of the gradient of the function at the current point.

# %% [markdown]
# ## b. Regularization for 2-D Data
# <img align="center" width="900" src="images/regularization-intutition1.png"  >

# %% [markdown]
# # 3. Cost Functions for Ridge, Lasso, and ElasticNet Regression

# %% [markdown]
# ## a. Cost Function for Standard Linear Regression
# $$\text{Cost Function} = \sum_{i=1}^n(y_i - \hat{y_i})^2 \hspace{19 cm}$$<br>
# $$\text{Cost Function} = \sum_{i=1}^n(y_i  - \sum_{j=1}^m x_{ij}\beta_j )^2 \hspace{18 cm}$$<br>
#
# - Solve the model parameters analytically and arrive at a closed form solution by setting the gradient of loss function equal to zero and solving the resultant equation for the coefficient vector $\beta$, using matrix formulation or otherwise.
#
# $ \hspace{2cm}    y = Xb$<br>
# $ \hspace{2cm}    X^Ty = X^TXb$<br>
# $\hspace{2cm}    (X^TX)^{-1}X^Ty = (X^TX)^{-1}(X^TX)b$<br>
# $ \hspace{2cm}    (X^TX)^{-1}X^Ty = Ib$<br>
# $\hspace{2cm}    b = (X^TX)^{-1}X^TY$<br>
#
#
# <font face = "Courier New" color=magenta size=3>$$\large \beta = (X^TX)^{-1}X^TY\hspace{17 cm}$$</font><br>
#
# - Use Gradient Descent, which is an iterative optimization algorithm used to find the local minima of a differentiable function. The main idea is to take repeated steps in the opposite direction of the gradient of the function at the current point.

# %% [markdown]
# ## b. Cost Function for Ridge Regression (L2)
# $$ \text{Cost Function} = \sum_{i=1}^n(y_i - \hat{y_i})^2 + \text{Penalty Term}\hspace{17 cm}$$<br>
# $$\text{Cost Function} = \sum_{i=1}^n(y_i  - \sum_{j=1}^m x_{ij}\beta_j )^2  + \lambda  \times  \sum_{i=1}^m {\beta_i}^2 \hspace{16 cm}$$<br>
# - The penalty term $\lambda  \times  \sum_{i=1}^m {\beta_i}^2$  maintains a trade-off between `fit of the model to the data` and `square of norm of the coefficients`.
#     - If model is fitted poorly, the first term is large.
#     - If coefficients have high values (overfit model), the second term (penalty term) is large.
# - Large $\lambda$ penalizes coefficient values more.
# - The cost function of Ridge Regression is still quadratic, and we can find closed form solution by taking gradient with respect to $\mathbf{\beta}$, after gradient we have a solution of the ridge regression.
#
# <font face = "Courier New" color=magenta size=3>$$\large \beta = (X^TX + \lambda I)^{-1}X^TY\hspace{17 cm}$$</font>
#
#
# - $\lambda = 0$, we have non-regularized solution.
# - $\lambda = \infty$, the regression coefficients approaches to zero value but not exactly zero.
# - `L2` regularization forces the weights to be small but does not make them zero and does non-sparse solution.
# - `L2` is not robust to outliers as square terms blows up the error differences of the outliers and the regularization term tries to fix it by penalizing the weights
# - Ridge regression performs better when all the input features influence the output and all with weights are of roughly equal size.

# %% [markdown]
# ## c. Cost Function for Lasso Regression (L1)
# $$ \text{Cost Function} = \sum_{i=1}^n(y_i - \hat{y_i})^2 + \text{Penalty Term}\hspace{17 cm}$$<br>
#
# $$\text{Cost Function} = \sum_{i=1}^n(y_i  - \sum_{j=1}^m x_{ij}\beta_j )^2  + \lambda  \times  \sum_{i=1}^m {|\beta_i|} \hspace{16 cm}$$<br>
#
#
# - Lasso regularization is referred to as `Least Absolute Shrinkage or Selection Operator`.
# - L1 norm shrinks the parameters to zero.
#     - When input features have weights closer to zero that leads to sparse L1 norm. In Sparse solution majority of the input features have zero weights and very few features have non-zero weights.
# - Not all input features have the same influence on the prediction. L1 norm will assign a zero weight to features with less predictive power.
# - Lasso regularization does feature selection. It does this by assigning insignificant input features with zero weight and useful features with a non-zero weight.
# - Since Lasso use L1 norm, so it is not effected much by outliers as compared to Ridge.
# - Lasso regression gives us sparse solution.
# >- **Why Lasso have NO closed form solution?** Due to L1 penalty the cost function is no longer continuously differentiable, therefore, no closed form solution exist for LASSO Regression. (On the contrary we do have a closed form solution for Ridge Regression). One can use discrete optimization techniques like Pathwise Coordinate Descent, Least Angle Regression, Forward Stepwise Regression to minimize the cost function for Lasso Regression.

# %% [markdown]
# ## d. Graphical Visualization
# <img align="center" width="700" src="images/p128.png"  >

# %% [markdown]
# - The two contuour plots are of the least square function (RSS) and the black dot at the center represents the minimum of the function.
# - The penalty term for Ridge regression is represented by a circle, while the penalty term for Lasso regression is represented by a diamond, with minimum at the origin.
# - For Ridge as well as for Lasso regression, we want to minimize both the RSS and the penalty term function.
# - In case of Lasso regression, there is a high probability that the contour plot will meet with the diamond at the point
#     - either along the $\beta_2$ line in which case $\beta_1$ will become zero or
#     - along the $\beta_1$ line in which case $\beta_2$ will become zero.
# - Therefore, the Lasso regression gives us a sparse solution as it makes some of the parameters exactly zero
# - In case of Ridge regression, irrelevant features get a very small coefficient and in Lasso regression irrelevant features get exactly zero coefficient and are not considered in the model. That is the reason we say that Lasso do Feature Selection, and it does this by assigning insignificant input features with zero weight and useful features with a non-zero weight.
# - Moreover, Lasso use L1 norm, so it is not effected much by outliers as compared to Ridge.
# - It seems as Lasso is better than Ridge, but Lasso is computationally more expensive than Ridge, because it has a non-differentiable cost function and do not have a closed form solution like Ridge.

# %% [markdown]
# ## d. Cost Function for ElasticNet Regression (L1+L2)
# - Ridge and Lasso are special cases of elastic net regression.
# - ElasticNet Regression combines the strength of both, but require tuning of two hyper-parameters $\lambda_1$ and $\lambda_2$.
# - Ridge and Lasso are special cases of ElasticNet regression.
#
# $$ \text{Cost Function} = \sum_{i=1}^n(y_i - \hat{y_i})^2 + \text{Penalty Term}\hspace{17 cm}$$<br>
# $$ \text{Cost Function} = \sum_{i=1}^n(y_i - \hat{y_i})^2 + \lambda_1 \times \sum_{i=1}^m {\beta_i}^2 + \lambda_2 \times \sum_{i=1}^m {|\beta_i|}\hspace{14.5 cm}$$<br>
#
# - When $\lambda_1 = 0$ and $\lambda_2 = 0$, we get non-regularized solution.
# - When $\lambda_1 \gt 0$ and $\lambda_2 = 0$, we get Ridge regression.
# - When $\lambda_1 = 0$ and $\lambda_2 \gt 0$, we get Lasso regression.
# - When $\lambda_1 \gt 0$ and $\lambda_2 \gt 0$, we get ElasticNet regression.

# %% [markdown]
# ## f. Scikit-Learn Estimators for Regularization
#
# <h3 align="center"><div class="alert alert-success" color=magenta style="margin: 20px">In sklearn, an estimator is a Python object that implements the fit(X, y) and predict(X) methods </h3>
#
#
# <center><font face = "Courier New" color=green size=6>from &nbsp;&nbsp; sklearn.</font><font face = "Courier New" color=blue size=6>model_family</font> <font face = "Courier New" color=green size=6>&nbsp;&nbsp;  import </font><font face = "Courier New" color=magenta size=6>&nbsp;&nbsp; Estimator</font></center><br>
#
# <font face = "Courier New" color=green size=5>&nbsp; from sklearn.</font><font face = "Courier New" color=blue size=5>linear_model</font> <font face = "Courier New" color=green size=5>&nbsp; import </font><font face = "Courier New" color=magenta size=5>Ridge, Lasso, ElasticNet  </font><br>
#
#
# <font face = "Courier New" color=green size=5>&nbsp; from sklearn.</font><font face = "Courier New" color=blue size=5>linear_model</font> <font face = "Courier New" color=green size=5>&nbsp; import </font><font face = "Courier New" color=magenta size=5>RidgeCV, LassoCV, ElasticNetCV</font><br>

# %% [markdown]
# # Example 1: Ridge Regression (Intutition)

# %%
from sklearn import datasets
from matplotlib import pyplot as plt
X, y = datasets.make_regression(n_samples=100,
                        n_features=1,
                        noise=20,
                        n_targets=1,
                        random_state=13)
plt.scatter(X,y);

# %% [markdown]
# **Use Standard Linear Regression to calculate Coefficients:**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
print("𝛽1: ", lr.coef_)
print("𝛽0: ",lr.intercept_)
# Out:
# 𝛽1:  [27.82809103]
# 𝛽0:  -2.2947445586769795

# %% [markdown]
# **Use Ridge Regression to calculate Coefficients (with `alpha=0`):**

# %%
from sklearn.linear_model import Ridge

rr1 = Ridge(alpha=0)
rr1.fit(X,y)
print("𝛽1: ", rr1.coef_)
print("𝛽0: ",rr1.intercept_)
# Out:
# 𝛽1:  [27.82809103]
# 𝛽0:  -2.29474455867698

# %% [markdown]
# **Use Ridge Regression to calculate Coefficients (with `alpha=10`):**

# %%
rr2 = Ridge(alpha=10)
rr2.fit(X,y)
print("𝛽1: ", rr2.coef_)
print("𝛽0: ",rr2.intercept_)
# Out:
# 𝛽1:  [24.9546267]
# 𝛽0:  -2.1269130035235726

# %% [markdown]
# **Use Ridge Regression to calculate Coefficients (with `alpha=100`):**

# %%
rr3 = Ridge(alpha=100)
rr3.fit(X,y)
print("𝛽1: ", rr3.coef_)
print("𝛽0: ",rr3.intercept_)
# Out:
# 𝛽1:  [12.93442104]
# 𝛽0:  -1.4248441496033308

# %%
# For Lasso with large alpha value the regression coefficient becomes zero
from sklearn.linear_model import Lasso
a = Lasso(alpha=100)
a.fit(X,y)
print("𝛽1: ", a.coef_)
print("𝛽0: ",a.intercept_)
# Out:
# 𝛽1:  [0.]
# 𝛽0:  -0.669378360869679

# %% [markdown]
# **Visualize the Regression Lines with different alpha values:**

# %%
plt.plot(X, y, 'b.')
plt.plot(X, rr1.predict(X), color='red', label='alpha=0')
plt.plot(X, rr2.predict(X), color='green', label='alpha=10')
plt.plot(X, rr3.predict(X), color='orange', label='alpha=100')
plt.legend();

# %% [markdown]
# # Example 2: Ridge Regression (Prevent Overfitting)

# %%
import pandas as pd
df = pd.read_csv("datasets/Melbourne_housing.csv")
df
# Out:
#            Suburb  Rooms Type Method        SellerG  Distance  \
# 0      Abbotsford      2    h      S         Biggin       2.5
# 1      Abbotsford      2    h      S         Biggin       2.5
# 2      Abbotsford      3    h     SP         Biggin       2.5
# 3      Abbotsford      3    h     PI         Biggin       2.5
# 4      Abbotsford      4    h     VB         Nelson       2.5
# ...           ...    ...  ...    ...            ...       ...
# 27239  Yarraville      4    h     PI            Jas       6.3
# 27240  Yarraville      2    h     SP        Sweeney       6.3
# 27241  Yarraville      2    t      S            Jas       6.3
# 27242  Yarraville      3    h     SP  hockingstuart       6.3
# 27243  Yarraville      2    h     PI             RW       6.3
#
#                   Regionname  Propertycount               CouncilArea  \
# 0      Northern Metropolitan         4019.0        Yarra City Council
# 1      Northern Metropolitan         4019.0        Yarra City Council
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27244 entries, 0 to 27243
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27244 non-null  object
#  1   Rooms          27244 non-null  int64
#  2   Type           27244 non-null  object
#  3   Method         27244 non-null  object
#  4   SellerG        27244 non-null  object
#  5   Distance       27244 non-null  float64
#  6   Regionname     27244 non-null  object
#  7   Propertycount  27244 non-null  float64
#  8   CouncilArea    27244 non-null  object
#  9   Bedroom2       27244 non-null  float64
#  10  Bathroom       27244 non-null  float64
#  11  Car            27244 non-null  float64
#  12  Landsize       27244 non-null  float64
#  13  BuildingArea   27244 non-null  float64
#  14  Price          27244 non-null  float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# ### Handle categorical variables:

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Rooms  Distance  Propertycount  Bedroom2  Bathroom  Car  Landsize  \
# 0      2       2.5         4019.0       2.0       1.0  1.0     202.0
# 1      2       2.5         4019.0       2.0       1.0  0.0     156.0
# 2      3       2.5         4019.0       3.0       2.0  0.0     134.0
# 3      3       2.5         4019.0       3.0       2.0  1.0      94.0
# 4      4       2.5         4019.0       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 0      160.2564  1480000.0                  0  ...
# 1       79.0000  1035000.0                  0  ...
# 2      150.0000  1465000.0                  0  ...
# 3      160.2564   850000.0                  0  ...
# 4      142.0000  1600000.0                  0  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 0                                    0                                  0
# 1                                    0                                  0
# ...

# %% [markdown]
# ### Train | Test Split:

# %%
X = df.drop('Price', axis=1)
y = df['Price']
X.shape, y.shape
# Out:
# ((27244, 744), (27244,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %% [markdown]
# ### Use Standard Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
print("R2 score on Training set: ", lr.score(X_train, y_train))
print("R2 score on Training set: ", r2_score(y_train, lr.predict(X_train)))
# Out:
# R2 score on Training set:  0.6827792395792723
# R2 score on Training set:  0.6827792395792723

# %%
print("R2 score on Test set: ", lr.score(X_test, y_test))
print("R2 score on Test set: ", r2_score(y_test, lr.predict(X_test)))
# Out:
# R2 score on Test set:  0.1385368316175627
# R2 score on Test set:  0.1385368316175627

# %% [markdown]
# > **Above model is Overfitting, because it is giving reasonably good results on training data but very bad results on test data :(**

# %% [markdown]
# ### Use Ridge Linear Regression

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=1)
rr.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
print("R2 score on Training set: ", rr.score(X_train, y_train))
print("R2 score on Training set: ", r2_score(y_train, rr.predict(X_train)))
# Out:
# R2 score on Training set:  0.6796668251040214
# R2 score on Training set:  0.6796668251040214

# %%
print("R2 score on Test set: ", rr.score(X_test, y_test))
print("R2 score on Test set: ", r2_score(y_test, rr.predict(X_test)))
# Out:
# R2 score on Test set:  0.6701765758295282
# R2 score on Test set:  0.6701765758295282

# %% [markdown]
# > **Above model is a good fit, because it is giving almost same results on both training and testing data :)**
#
# > Try increasing the alpha value to 10000 and see how the model underfits.
#
# > On similar pattern, check out the performance of using Lasso and ElasticNet Regression on this dataset.

# %% [markdown]
# # Example 3: Impact of Alpha Values of Ridge Regression

# %% [markdown]
# ### Load Dataset:

# %%
from sklearn.datasets import load_diabetes
diabetes=load_diabetes(as_frame=True)

# %%
print(diabetes.get('DESCR'))
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X = diabetes.get('data')    #diabetes.data      #diabetes['data']
y = diabetes.get('target')  #diabetes.target    #diabetes['target']

# %% [markdown]
# ### Train | Test Split:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %% [markdown]
# ### Use Standard Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)             # Fit a linear regression on the training data
lr_pred = lr.predict(X_test)           # Use this model to predict the test data
print(pd.Series(lr.coef_, index = X.columns)) # Print coefficients
# Out:
# age    -31.805370
# sex   -214.671676
# bmi    445.137506
# bp     376.354944
# s1    -802.451729
# s2     525.951855
# s3     106.399671
# s4     172.311225
# s5     799.479042
# s6      57.167687
# dtype: float64

# %% [markdown]
# ### Use Ridge Regression with `alpha=0`

# %%
from sklearn.linear_model import Ridge
rr1=Ridge(alpha=0)
rr1.fit(X_train, y_train)     # Fit a ridge regression on the training data with alpha=0
rr1.predict(X_test)           # Use this model to predict the test data
print(pd.Series(rr1.coef_, index=X.columns)) # Print coefficients
# Out:
# age    -31.805370
# sex   -214.671676
# bmi    445.137506
# bp     376.354944
# s1    -802.451729
# s2     525.951855
# s3     106.399671
# s4     172.311225
# s5     799.479042
# s6      57.167687
# dtype: float64

# %% [markdown]
# ### Use Ridge  Regression with `alpha=1`

# %%
from sklearn.linear_model import Ridge
rr1=Ridge(alpha=1)
rr1.fit(X_train, y_train)     # Fit a ridge regression on the training data with alpha=1
rr1.predict(X_test)           # Use this model to predict the test data
print(pd.Series(rr1.coef_, index=X.columns)) # Print coefficients
# Out:
# age     38.755675
# sex    -52.971195
# bmi    234.615921
# bp     193.163458
# s1      27.821247
# s2      -2.904829
# s3    -139.601939
# s4     116.142663
# s5     242.458241
# s6     101.463602
# dtype: float64

# %% [markdown]
# ### Use Ridge  Regression with `alpha=10000`

# %%
from sklearn.linear_model import Ridge
rr1=Ridge(alpha=10000)
rr1.fit(X_train, y_train)    # Fit a ridge regression on the training data with alpha=10000         
rr1.predict(X_test)         # Use this model to predict the test data
print(pd.Series(rr1.coef_, index=X.columns)) # Print coefficients
# Out:
# age    0.025811
# sex    0.004663
# bmi    0.062004
# bp     0.052696
# s1     0.026870
# s2     0.021778
# s3    -0.044786
# s4     0.049758
# s5     0.067498
# s6     0.042867
# dtype: float64

# %% [markdown]
# ### Use Lasso Regression with `alpha=10000`

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=10000)      # Fit a Lasso regression on the training data with alpha=10000         
lasso_reg.fit(X_train, y_train)    # Use this model to predict the test data         
lasso_reg.predict(X_test)           
print(pd.Series(lasso_reg.coef_, index=X.columns))
# Out:
# age    0.0
# sex    0.0
# bmi    0.0
# bp     0.0
# s1     0.0
# s2     0.0
# s3    -0.0
# s4     0.0
# s5     0.0
# s6     0.0
# dtype: float64

# %% [markdown]
# ### A Quick Comparison
#
# **Ridge/L2 Regularization**
# - L2 regularization penalizes sum of square weights.
# - L2 has a non sparse solution
# - L2 has one solution
# - L2 has no feature selection
# - L2 is not robust to outliers
# - L2 gives better prediction when output variable is a function of all input features
# - L2 regularization is able to learn complex data patterns
#
# **Lasso/L1 Regularization**
# - L1 penalizes sum of absolute value of weights.
# - L1 has a sparse solution
# - L1 has multiple solutions
# - L1 has built in feature selection
# - L1 is robust to outliers
# - L1 generates model that are simple and interpretable but cannot learn complex patterns

# %% [markdown]
# <center><h3 align="center"><div class="alert alert-success" style="margin: 20px">How to choose the best alpha value for Ridge, Lasso and ElasticNet Regression?</h3></center>

# %% [markdown]
# # Task To Do

# %%
import pandas as pd
teams = pd.read_csv("datasets/teams.csv")
teams
